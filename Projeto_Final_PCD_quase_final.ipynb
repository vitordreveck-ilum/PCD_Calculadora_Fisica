# %% [markdown]
# # Modelo documentação

# %%
def funcao_generica():
    """Descrição do funcionamento da função

    Argumentos:
        argumento_1 (tipo): Descrição do argumento
        argumento_2 (tipo): Descrição do argumento
            (padrão é [valor padrão do argumento, se houver])

    Retornos:
        tipo: descrição do retorno
    """

    # código da função

def funcao_exemplo(num, potencia, printar=False):
    """Recebe um número real e o eleva à potência inserida

    Argumentos:
        num (float): Base da potência
        potencia (int): Potência
        printtar (bool): Parâmetro que define se o valor resultante será impresso
            (padrão é False)

    Retornos:
        float: valor num elevado à potencia
    """

    return num ** potencia

# %% [markdown]
# # Variáveis gerais

# %%
def calcula_massa(velocidade = None, energia_cinetica = None, energia_potencial_gravitacional = None,
                  aceleracao_gravitacional = None, altura = None):
  """Calcula a massa a partir de velocidade e energia cinética ou energia potencial gravitacional, aceleração gravitacional e altura.

    Argumentos:
        velocidade (None ou float): Velocidade em metros por segundo (m/s)
            (padrão é None)
        energia_cinetica (None ou float): Energia cinética em joule (J)
            (padrão é None)
        energia_potencial_gravitacional (None ou float): Energia potencial gravitacional em joule (J)
            (padrão é None)
        aceleracao_gravitacional (None ou float): Aceleração gravitacional em metros por segundo ao quadrado (m/s**2)
            (padrão é None)
        altura (None ou float): Altura em metros (m)
            (padrão é None)
        densidade (None ou float): Densidade em quilogramas por metro cúbico (kg/m**3)
            (padrão é None)
        volume (None ou float): Volume em metros cúbicos (m**3)
            (padrão é None)

    Retornos:
        float: massa em quilogramas (kg)
  """

  massa = 0

  if velocidade != None and energia_cinetica != None:
    massa = 2*energia_cinetica/velocidade**2

  elif energia_potencial_gravitacional != None and aceleracao_gravitacional != None and altura != None:
    massa = energia_potencial_gravitacional/(aceleracao_gravitacional*altura)

  return massa

def calcula_velocidade(massa, energia_cinetica):
  """Calcula a velocidade a partir da massa e energia cinética.

    Argumentos:
        massa (None ou float): Massa em quilogramas (kg)
        energia_cinetica (None ou float): Energia cinética em joule (J)

    Retornos:
        float: velocidade em metros por segundo (m/s)
  """

  velocidade = (2*energia_cinetica/massa)**0.5

  return velocidade

def calcula_altura(energia_potencial_gravitacional, massa, aceleracao_gravitacional):
  """Calcula a altura a partir da energia potencial gravitacional, massa e açeleração gravitacional

    Argumentos:
        energia_potencial_gravitacional (bool ou float): Energia potencial gravitacional em joule (J)
        massa (bool ou float): Massa em quilogramas (kg)
        aceleracao_gravitacional (bool ou float): aceleração gravitacional em metros por segundo ao quadrado (m/s**2)

    Retornos:
        float: altura em metros (m)
  """

  altura = energia_potencial_gravitacional/(aceleracao_gravitacional*massa)

  return altura

# %% [markdown]
# # Energia

# %%
def calcula_energia_cinetica(massa = None, velocidade = None, energia_potencial = None, energia_mecanica = None):
  """Calcula a energia cinética a partir da massa e velocidade ou energia potencial e energia mecânica.

    Argumentos:
        massa (None ou float): Massa em quilogramas (kg)
            (padrão é None)
        velocidade (None ou float): Velocidade em metros por segundo (m/s)
            (padrão é None)
        energia_potencial (None ou float): Energia potencial em joule (J)
            (padrão é None)
        energia_mecanica (None ou float): Energia mecânica em joule (J)
            (padrão é None)

    Retornos:
        float: energia cinética em joule (J)
  """

  energia_cinetica = 0

  if massa != None and velocidade != None:
    energia_cinetica = (0.5)*massa*(velocidade)**2

  elif energia_mecanica != None and energia_potencial != None:
    energia_cinetica = energia_mecanica - energia_potencial

  return energia_cinetica


def calcula_energia_potencial_gravitacional(massa, aceleracao_gravitacional, altura):
  """Calcula a energia potencial gravitacional a partir da massa, aceleração gravitacional e altura

    Argumentos:
        massa (float): Massa em quilogramas (kg)
        aceleracao_gravitacional (bool ou float): Aceleração gravitacional em metros por segundo ao quadrado (m/s**2)
        altura (float): Altura em metros (m)

    Retornos:
        float: energia gravitacional em joule (J)
  """

  energia_potencial_gravitacional = massa*aceleracao_gravitacional*altura

  return energia_potencial_gravitacional


def calcula_aceleracao_gravitacional(energia_potencial_gravitacional, massa, altura):
  """Calcula a aceleração gravitacional a partir de energia potencial gravitacional, massa e altura

    Argumentos:
        energia_potencial_gravitacional (bool ou float): Energia potencial gravitacional em joule (J)
        massa (bool ou float): Massa em quilogramas (kg)
        altura (bool ou float): Altura em metros (m)

    Retornos:
        float: aceleração gravitacional em metros por segundo ao quadrado (m/s**2)
  """

  aceleracao_gravitacional = energia_potencial_gravitacional/(massa*altura)

  return aceleracao_gravitacional


def calcula_energia_mecanica(energia_cinetica, energia_potencial):
  """Calcula a energia mecânica a partir de energia cinética e energia potencial

    Argumentos:
        energia_cinetica (loat): Energia cinética em joule (J)
        energia_potencial (float): Energia potencial em joule (J)

    Retornos:
        float: energia mecânica em joule (J)
  """


  energia_mecanica = energia_cinetica + energia_potencial

  return energia_mecanica

def calcula_energia_potencial_elastica(constante_elastica, elongacao):
  """Calcula a energia potencial elástica a partir da constante elástica e elongação

    Argumentos:
        constante_elastica (float): Constante elástica em newton por metro (N/m)
        elongacao (float): Elongação em metros (m)

    Retornos:
        float: energia potencial elástica em joule (J)
  """

  energia_potencial_elastica = (0.5)*constante_elastica*(elongacao)**2

  return energia_potencial_elastica


def calcula_energia_potencial(energia_cinetica, energia_mecanica):
  """Calcula a energia potencial a partir de energia cinética e energia mecânica

    Argumentos:
        energia_cinetica (float): Energia cinética em joule (J)
        energia_mecanica (float): Energia mecânica em joule (J)

    Retornos:
        float: energia potencial em joule (J)
  """

  energia_potencial = energia_mecanica - energia_cinetica

  return energia_potencial

# %% [markdown]
# ### Função Horária das Posições

# %%
import pandas as pd
from matplotlib import pyplot as plt

def funcao_horaria_posicoes(posicao_inicial, velocidade_inicial, tempo, aceleracao):
  """Fornece a posição através da função horária das posições, partindo de posição inicial, velocidade inicial, tempo e aceleração.

    Argumentos:
        posicao_inicial (float): Posição inicial em metros (m)
        velocidade_inicial (float): Velocidade inicial em metros por segundo (m/s)
        tempo (float): Tempo em segundos (s)
        aceleração (float): Aceleração em metros por segundo ao quadrado (m/s**2)

    Retornos:
        float: posição em metros (m)
  """

  posicao = posicao_inicial + velocidade_inicial * tempo + (aceleracao * tempo**2)/2
  return posicao

def plotar_funcao_horaria_posicoes(tempo_final, tempo_inicial = 0, aceleracao = 0, posicao_inicial = 0, velocidade_inicial = 0, passo = 0):
  """Plota o gráfico da função horária das posições a partir dos parâmetros inseridos

    Argumentos:
        tempo_final (float): Tempo final em segundos (s)
        tempo_inicial (float): Tempo inicial em segundos (s)
            (padrão é 0)
        aceleracao (float): Aceleração em metros por segundo ao quadrado (m/s**2)
            (padrão é 0)
        posicao_inicial (float): Posição inicial em metros (m)
            (padrão é 0)
        velocidade_inicial (float): Velocidade inicial em metros por segundo (m/s)
            (padrão é 0)
        passo (float): Intervalo entre as medições em segundos (s)
            (padrão é 1)

    Retornos:
        matplotlib.axes._axes.Axes: gráfico da função horária das posições de posição (m) por tempo (s).
  """

  tempos = []
  posicoes = []
  data_frame = pd.DataFrame(columns =['Tempo (s)', 'Posição (m)'])
  for tempo in range (tempo_inicial, tempo_final, passo):
    tempos.append(tempo)
    posicoes.append(funcao_horaria_posicoes(posicao_inicial = posicao_inicial, velocidade_inicial = velocidade_inicial, tempo = tempo, aceleracao = aceleracao))
    tempo += passo
  data_frame['Tempo (s)'] = tempos
  data_frame['Posição (m)'] = posicoes

  data_frame.plot.scatter('Tempo (s)', 'Posição (m)', color = 'black')
  plt.show()

# %% [markdown]
# # Força elástica

# %%
#f= força em newtons
#k= constante newtons/metro
#x= deformação em metros
#e= energia
#cf= comprimento final da mola
#ci= comprimento inical da mola

#é necessário fornecer o valor da constante elastica, pois esta muda de acordo com o material

from math import sqrt

def calcula_forca_elastica(k, x):
    """Calcula a força elástica a partir da constante elástica e da deformação da mola

    Argumentos:
        k (float): constante elástica (newtons/metro)
        x (float): deformação da mola (metros)

    Retornos:
        f (float): força elástica (newton)
    """
    f = k * x
    return f

def calcula_deformacao_da_mola (k = None, e = None, cf = None, ci = None, f = None):
    """Calcula a deformação da mola a partir da constante elástica e da força elástica ou da energia elástica e da constante elástica ou pela diferença de comprimento das molas

    Argumentos:
        k (float): constante elástica (newtons/metro)
          (padrâo é None)
        f (float): força elástica (newton)
          (padrâo é None)
        e (float): energia potencial elástica
          (padrâo é None)
        cf (float): comprimento final da mola
          (padrâo é None)
        ci (float): comprimento inicial da mola
          (padrâo é None)

    Retornos:
        x (float): deformação da mola (metros)
    """

    if f != None and k != None:
        x = f/k

    elif e!= None and k != None:
        x = sqrt((e*2)/k)

    elif cf !=None and ci != None:
        x = cf - ci

    return x

def calcula_constante_elastica(x=None, e=None, f=None):
    """Calcula a constante elástica a partir da deformação da mola e da força elástica ou da energia elástica e da deformação da mola

    Argumentos:
        x (float): deformação da mola (metros)
            (padrão é None)
        f (float): força elástica (newton)
            (padrão é None)
        e (float): energia elástica (J)
            (padrão é None)


    Retornos:
        k (float): constante da mola (newton/metros)
    """
    if f != None and x!= None:
        k = f/x
    elif e!= None and x!= None:
        k = (2*e)/x**2

    return k

def calcula_elongacao(constante_elastica = None, energia_potencial_elastica = None, forca_elastica = None, comprimento_inicial = None, comprimento_final = None):
  """Calcula a elongação a partir de constante elástica e energia potencial elástica ou constante elástica e força elástica ou comprimento inicial e comprimento final

    Argumentos:
        constante_elastica (None ou float): Constante elástica em newton por metro (N/m)
            (padrão é False)
        energia_potencial_elastica (None ou float): Energia potencial elástica em joule (J)
            (padrão é False)
        forca_elastica (None ou float): Força elástica em newton (N)
            (padrão é False)
        comprimento_inicial (None ou float): Comprimento inicial em metros (m)
            (padrão é False)
        comprimento_final (None ou float): Comprimento final em metros (m)
            (padrão é False)

    Retornos:
        float: elongação em metros (m)
  """

  elongacao = 0

  if constante_elastica != None and energia_potencial_elastica != None:
    elongacao = (2*energia_potencial_elastica/constante_elastica)**0.5

  elif forca_elastica != None and constante_elastica != None:
    elongacao = forca_elastica/constante_elastica

  elif comprimento_final !=None and comprimento_inicial != None:
    elongacao = comprimento_final - comprimento_inicial

  return elongacao

# %% [markdown]
# #Função horária das velocidades

# %%
#V=Vo+at
#v: velocidade final
#vo:velocidade inicial
#a: aceleração
#t: tempo

import pandas as pd
import matplotlib.pyplot as plt



def velocidade_final (vo, a, t):
    """ A função velocidade_final, calcula o valor da velocidade final, tendo como dados a velocidade inicial, a aceleração e o tempo

    Argumentos:
        vo (int ou float): velocidade inicial
        a (int ou float): aceleração
        t (int ou float): tempo

    Return:
        A função retorna o valor numérico da velocidade final
    """
    v=vo+a*t
    return v

def dataframe(vo, a, t_inicial, t_final, passo):
    """ A função dataframe, define um DataFrame, que será utilizado para o gráfico de velocidade por tempo, tendo como dados o tempo e a velocidade final

    Argumentos:
        vo (int ou float): velocidade inicial
        a (int ou float): aceleração
        t_inicial (int): tempo inicial
        t_final (int): tempo final
        passo (int): intervalo entre os tempos

    Return:
        A função retorna um DataFrame de velocidade e tempo
    """
    t = [i for i in range(t_inicial, t_final + 1, passo)]
    dados= {'tempo(segundos)':t, 'velocidade(m/s)': [velocidade_final(vo, a, tempo) for tempo in t]}
    df = pd.DataFrame(dados)
    return df

def grafico (df):
    """ A função gráfico plota um gráfico a partir do DataFrame

    Argumentos:
        df (DataFrame): dataframe com os dados para o gráfico

    Return:
        A função retorna um gráfico
    """

    df = df.plot(x='tempo(segundos)', y='velocidade(m/s)')
    plt.xlabel('Tempo (segundos)')
    plt.ylabel('Velocidade (m/s)')
    plt.title('Gráfico de Velocidade x Tempo')
    plt.show()

def plotar_funcao_horaria_das_velocidades(vo, a, t_inicial, t_final, passo):
  df = dataframe(vo, a, t_inicial, t_final, passo)
  grafico(df)

# %% [markdown]
# # MRU

# %% [markdown]
# 1ª Formula : S = So + V . t

# %%
    # S = so + v .t

    # So = (v - t) / S

    # V = (So - t) / S

    # t = (So - v) /s

# %%
def sorvete(sfinal=None, sinicial=None, velocidade=None, tempo=None):

    # S = so + v .t
    if sinicial != None and velocidade != None and tempo != None:
        sfinal = sinicial + velocidade * tempo
        return sfinal

    # So = (v - t) / S
    elif sfinal != None and velocidade != None and tempo != None:
        sinicial = sfinal - velocidade * tempo
        return sinicial

    # V = (So - t) / S
    elif sfinal != None and sinicial != None and tempo != None:
        velocidade = (sfinal - sinicial) / tempo
        return velocidade

    # t = (So - v) /s
    elif sfinal != None and sinicial != None and velocidade != None:
        tempo = (sfinal - sinicial) / velocidade
        return tempo

    else:
        return "Parâmetros insuficientes ou mal definidos"

# %% [markdown]
# 2º Fórmula - Velocide Média

# %% [markdown]
# Vm = S - So / T - To
#
# S = Vm . (T - To)+So
#
# So = S - Vm . (t - To)
#
# T = (S- So / Vm ) + To

# %%
def velocidade_media(vmedia = None , sfinal = None, sinicial = None, tfinal = None, tinicial = None):

    # Vm = S - So / T - To

    if  sfinal != None and sinicial != None and tfinal != None and tinicial != None:
        vmedia = (sfinal - sinicial)/(tfinal-tinicial)
        return vmedia

    # S = Vm . (T - To)+So

    elif vmedia != None and sinicial != None and tfinal != None and tinicial != None:
        sfinal = vmedia * ( tfinal - tinicial) + sinicial
        return sfinal

    # So = S - Vm . (t - To)
    elif vmedia != None and sfinal != None and tfinal != None and tinicial != None:
        sinicial = sfinal - vmedia * (tfinal - tinicial)
        return sinicial

    # T = (S- So / Vm ) + To
    elif vmedia != None and sfinal != None and sinicial != None and tinicial != None:
        tfinal = ( sfinal - sinicial ) / vmedia + tinicial
        return tfinal

    # To = T - (S-So)/Vm
    elif vmedia != None and sfinal != None and sinicial != None and tfinal != None:
        tinicial = tfinal - (sfinal - sinicial)/vmedia
        return tinicial

# %% [markdown]
# #Interface

# %%
# ferramenta para mostrar títulos
def print_menu(titulo):
  """Exibe o título recebido de forma formatada

  Argumentos:
      titulo (str): Texto a ser exibido

  Retorno:
      None
  """
  
  print()
  print(f"{titulo:-^76}")

# aviso de resposta inválida
def opcao_invalida():
  """Exibe uma mensagem de opção inválida

  Argumentos:
      None

  Retorno:
      None
  """
  
  print()
  print('-'*76)
  print(f"{'OPÇÂO INVÁLIDA':^76}")
  print('-'*76)
  print()

# confirmação de resposta válida
def opcao_valida():
  """Exibe uma mensagem de opção válida

  Argumentos:
      None

  Retorno:
      None
  """
  
  print()
  print('='*76)

# mascote
def cateto():
  """Exibe uma imagem do gato (apelidado de Cateto) ao usuário como uma imagem de despedida

  Argumentos:
      None

  Retorno:
      None
  """

# Não é bonitinho? :3
  print(f"{'▄▀▄     ▄▀▄':^76}")
  print(f"{'▄█░░▀▀▀▀▀░░█▄':^76}")
  print(f"{'▄▄  █░░░░░░░░░░░█  ▄▄':^76}")
  print(f"{'█▄▄█ █░░▀░░┬░░▀░░█ █▄▄█':^76}")
  print('-'*76)


# função para coleta de respostas do usuário
def coleta_resposta(texto, opcoes = None, inteiro = False):
  """Coleta a resposta do usuário para diferentes perguntas, dependendo do contexto, e impede que ele insira uma resposta inválida

  Argumentos:
      texto (str): Texto a ser exibido ao usuário
      opcoes (None ou tupla): Tupla com as opções válidas para a pergunta em questão. Se nenhuma é informada, recebe None
        (padrão é None)
      inteiro (bool): Recebe a informação de se a resposta precisa (True) ou não (False) ser um inteiro
        (padrão é False)
  Retornos:
      Se opcoes == None e inteiro == True: a resposta convertida para inteiro (int)
      Se opcoes == None e inteiro == False: a resposta convertida para float e arredondada para duas casas (float)
      Se opcoes != None: a própria resposta inserida pelo usuário (str)
  """

# roda o loop enquanto o usuário não informar uma resposta válida
  while True:
    print(texto)
    try:
      if opcoes == None:
        answ = input("\n---->  ").strip()
        print()
        if inteiro:
          return int(answ)
        else:
          return round(float(answ), 2)
      else:
        answ = (str(input("\n---->  ")).strip()).lower()
        if answ in opcoes:
          opcao_valida()
          return answ
        else:
          opcao_invalida()
    except:
      opcao_invalida()

def menu_energia():
  """Menu de fórmulas envolvendo energia. Exibe todas as opções disponíveis (organizadas em submenus)
     e interage com o usuário para realizar os cálculos desejados, chamando as funções pertinentes.

  Argumentos:
      None

  Retorno:
      None
  """
# roda o loop enquanto o usuário não selecionar a opção "voltar"
  while True:
    print_menu(' ENERGIA ')
    opcao = coleta_resposta("""\n1- Energia Cinética
                                \n2- Energia potencial gravitacional
                                \n3- Energia potencial elástica
                                \n4- Energia mecânica
                                \n0- Voltar""", ('1', '2', '3', '4', '0'))
    if opcao == '1':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Massa e velocidade
                              \n2- Energia potencial e energia cinética
                              \n3- Velocidade e energia cinética
                              \n4- Energia potencial gravitacional, altura e velocidade
                              \n0- Voltar""", ('1', '2', '3', '4', '0'))
      if opcao == '1':
        massa = coleta_resposta("Insira a massa (kg)")
        vel = coleta_resposta("Insira a velocidade (m/s)")
        energia_cin = calcula_energia_cinetica(massa, vel)
      elif opcao == '2':
        energia_pot = coleta_resposta("Insira a energia potencial (J)")
        energia_mec = coleta_resposta("Insira a energia mecânica (J)")
        energia_cin = calcula_energia_cinetica(energia_potencial=energia_pot, energia_mecanica=energia_mec)
      elif opcao == '3':
        vel = coleta_resposta("Insira a velocidade (m/s)")
        energia_cin = coleta_resposta("Insira a energia cinética (J)")
        massa = calcula_massa(velocidade=vel, energia_cinetica=energia_cin)
        energia_cin = calcula_energia_cinetica(massa, vel)
      elif opcao == '4':
        energia_pot = coleta_resposta("Insira a energia potencial (J)")
        h = coleta_resposta("Insira a altura (m)")
        vel = coleta_resposta("Insira a velocidade (m/s)")

        massa = calcula_massa(energia_potencial_gravitacional=energia_pot, aceleracao_gravitacional=9.8, altura=h)
        energia_cin = calcula_energia_cinetica(massa, vel)
      else:
        break
      opcao_valida()
      print(f"A energia cinética é {energia_cin} J")
    elif opcao == '2':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Massa e altura
                              \n2- Velocidade, energia cinética e altura
                              \n0- Voltar""", ('1', '2', '0'))
      if opcao == '1':
        massa = coleta_resposta("Insira a massa (kg)")
        altura = coleta_resposta("Insira a altura (m)")
        energia_pot = calcula_energia_potencial_gravitacional(massa, 9.8, altura)
      elif opcao == '2':
        velocidade = coleta_resposta("Insira a velocidade (m/s)")
        energia_cin = coleta_resposta("Insira a energia cinética (J)")
        altura = coleta_resposta("Insira a altura (m)")
        massa = calcula_massa(velocidade=velocidade, energia_cinetica=energia_cin)
        energia_pot = calcula_energia_potencial_gravitacional(massa, 9.8, altura)
      else:
        break
      opcao_valida()
      print(f"A energia potencial gravitacional é {energia_pot} J")
    elif opcao == '3':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Constante elástica e elongação
                              \n2- Constante elástica e força elástica
                              \n3- Constante elástica, comprimento inicial e comprimento final
                              \n0- Voltar""", ('1', '2', '3', '0'))
      if opcao == '1':
        constante_el = coleta_resposta("Insira a constante elástica (N/m)")
        elong = coleta_resposta("Insira a elongação (m)")
        energia_pot_el = calcula_energia_potencial_elastica(constante_el, elong)
      elif opcao == '2':
        constante_el = coleta_resposta("Insira a constante elástica (N/m)")
        forca_el = coleta_resposta("Insira a força elástica (N)")
        elong = calcula_elongacao(constante_elastica=constante_el, forca_elastica=forca_el)
        energia_pot_el = calcula_energia_potencial_elastica(constante_el, elong)
      elif opcao == '3':
        constante_el = coleta_resposta("Insira a constante elástica (N/m)")
        comprimento_ini = coleta_resposta("Insira o comprimento inicial (m)")
        comprimento_fin = coleta_resposta("Insira o comprimento final (m)")
        elong = calcula_elongacao(comprimento_inicial=comprimento_ini, comprimento_final=comprimento_fin)
        energia_pot_el = calcula_energia_potencial_elastica(constante_el, elong)
      else:
        break
      opcao_valida()
      print(f"A energia potencial elástica é {energia_pot_el} J")
    elif opcao == '4':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Energia cinética e energia potencial
                              \n2- Massa, velocidade e energia potencial
                              \n3- Energia potencial, velocidade e altura
                              \n0- Voltar""", ('1', '2', '3', '0'))
      if opcao == '1':
        energia_cin = coleta_resposta("Insira a energia cinética (J)")
        energia_pot = coleta_resposta("Insira a energia potencial (J)")
        energia_mec = calcula_energia_mecanica(energia_cin, energia_pot)
      elif opcao == '2':
        massa = coleta_resposta("Insira a massa (kg)")
        vel = coleta_resposta("Insira a velocidade (m/s)")
        energia_pot = coleta_resposta("Insira a energia potencial (J)")
        energia_cin = calcula_energia_cinetica(massa, vel)
        energia_mec = calcula_energia_mecanica(energia_cin, energia_pot)
      elif opcao == '3':
        energia_pot = coleta_resposta("Insira a energia potencial (J)")
        vel = coleta_resposta("Insira a velocidade (m/s)")
        h = coleta_resposta("Insira a altura (m)")
        massa = calcula_massa(velocidade=vel, energia_potencial_gravitacional=energia_pot)
        energia_cin = calcula_energia_cinetica(massa, vel)
        energia_mec = calcula_energia_mecanica(energia_cin, energia_pot)
      else:
        break
      opcao_valida()
      print(f"A energia mecânica é {energia_mec} J")
    else:
      break

def menu_mola():
  """Menu de fórmulas envolvendo força elástica. Exibe todas as opções disponíveis (organizadas em submenus)
     e interage com o usuário para realizar os cálculos desejados, chamando as funções pertinentes.

  Argumentos:
      None

  Retorno:
      None
  """

# roda o loop enquanto o usuário não selecionar a opção "voltar"
  while True:
    print_menu(' FORÇA ELÁSTICA ')
    opcao = coleta_resposta("""\n1- Força elástica
              \n2- Elongação da mola
              \n3- Constante elástica
              \n0- Voltar""", ('1', '2', '3', '0'))

    if opcao == '1':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Constante elástica e elongação
                              \n2- Constante elástica, comprimento inicial e comprimento final
                              \n3- Energia potencial elástica e constante elástica
                              \n4- Elongação e energia potencial elástica
                              \n5- Comprimento inicial, comprimento final e energia potencial elástica
                              \n0- Voltar""", ('1', '2', '3', '4', '5', '0'))
      if opcao == '1':
        constante_el = coleta_resposta("Insira a constante elástica (N/m)")
        elong = coleta_resposta("Insira a elongação (m)")
        forca_el = calcula_forca_elastica(constante_el, elong)
      elif opcao == '2':
        constante_el = coleta_resposta("Insira a constante elástica (N/m)")
        comp_ini = coleta_resposta("Insira o comprimento inicial (m)")
        comp_fin = coleta_resposta("Insira o comprimento final (m)")
        elong = calcula_elongacao(comprimento_inicial=comp_ini, ccomprimento_final=comp_fin)
        forca_el = calcula_forca_elastica(constante_el, elong)
      elif opcao == '3':
        energia_pot_el = coleta_resposta("Insira a energia potencial elástica (J)")
        constante_el = coleta_resposta("Insira a constante elástica (N/m)")
        elong = calcula_elongacao(constante_elastica=constante_el, energia_potencial_elastica=energia_pot_el)
        forca_el = calcula_forca_elastica(constante_el, elong)
      elif opcao == '4':
        elong = coleta_resposta("Insira a elongação (m)")
        energia_pot_el = coleta_resposta("Insira a energia potencial elástica (J)")
        constante_el = calcula_constante_elastica(x=elong, e=energia_pot_el)
        forca_el = calcula_forca_elastica(constante_el, elong)
      elif opcao == '5':
        energia_pot_el = coleta_resposta("Insira a energia potencial elástica (J)")
        comp_ini = coleta_resposta("Insira o comprimento inicial (m)")
        comp_fin = coleta_resposta("Insira o comprimento final (m)")
        elong = calcula_elongacao(comprimento_inicial=comp_ini, cf=comp_fin)
        constante_el = calcula_constante_elastica(x=elong, e=energia_pot_el)
        forca_el = calcula_forca_elastica(constante_el, elong)
      else:
        break
      opcao_valida()
      print(f"A força elástica é {forca_el} N")
    elif opcao == '2':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Comprimento inicial e comprimento final
                              \n2- Força elástica e constante elástica
                              \n3- Energia potencial elástica e constante elástica
                              \n0- Voltar""", ('1', '2', '3', '0'))
      if opcao == '1':
        comp_ini = coleta_resposta("Insira o comprimento inicial (m)")
        comp_fin = coleta_resposta("Insira o comprimento final (m)")
        elong = calcula_elongacao(comprimento_inicial=comp_ini, comprimento_final=comp_fin)
      elif opcao == '2':
        forca_el = coleta_resposta("Insira a força elástica (N)")
        constante_el = coleta_resposta("Insira a constante elástica (N/m)")
        elong = calcula_elongacao(forca_elastica=forca_el, constante_elastica=constante_el)
      elif opcao == '3':
        energia_pot_el = coleta_resposta("Insira a energia potencial elástica (J)")
        constante_el = coleta_resposta("Insira a constante elástica (N/m)")
        elong = calcula_elongacao(constante_elastica=constante_el, energia_potencial_elastica=energia_pot_el)
      else:
        break
      opcao_valida()
      print(f"A elongação é {elong} m")
    elif opcao == '3':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Força elástica e elongação
                              \n2- Energia potencial elástica e elongação
                              \n3- Comprimento inicial, comprimento final e energia potencial elástica
                              \n4- Força elástica, comprimento inicial e comprimento final
                              \n0- Voltar""", ('1', '2', '3', '0'))
      if opcao == '1':
        forca_el = coleta_resposta("Insira a força elástica (N)")
        elong = coleta_resposta("Insira a elongação (m)")
        constante_el = calcula_constante_elastica(f=forca_el, x=elong)
      elif opcao == '2':
        energia_pot_el = coleta_resposta("Insira a energia potencial elástica (J)")
        elong = coleta_resposta("Insira a elongação (m)")
        constante_el = calcula_constante_elastica(e=energia_pot_el, x=elong)
      elif opcao == '3':
        comp_ini = coleta_resposta("Insira o comprimento inicial (m)")
        comp_fin = coleta_resposta("Insira o comprimento final (m)")
        energia_pot_el = coleta_resposta("Insira a energia potencial elástica (J)")
        elong = calcula_elongacao(comprimento_inicial=comp_ini, comprimento_final=comp_fin)
        constante_el = calcula_constante_elastica(e=energia_pot_el, x=elong)
      elif opcao == '4':
        forca_el = coleta_resposta("Insira a força elástica (N)")
        comp_ini = coleta_resposta("Insira o comprimento inicial (m)")
        comp_fin = coleta_resposta("Insira o comprimento final (m)")
        elong = calcula_elongacao(comprimento_inicial=comp_ini, comprimento_final=comp_fin)
        constante_el = calcula_constante_elastica(f=forca_el, x=elong)
      else:
        break
      opcao_valida()
      print(f"A constante elástica é {constante_el} N/m")
    else:
      break

def menu_movimento():
  """Menu de atividades gerais envolvendo movimento. Exibe todas as opções disponíveis (organizadas em submenus)
     e interage com o usuário para realizar os cálculos desejados, chamando as funções pertinentes.

  Argumentos:
      None

  Retorno:
      None
  """

# roda o loop enquanto o usuário não selecionar a opção "voltar"
  while True:
    print_menu(' MOVIMENTO ')
    opcao = coleta_resposta("""\n1- Velocidade média
              \n2- Velocidade
              \n3- Posição inicial
              \n4- Posição final
              \n5- Tempo inicial
              \n6- Tempo final
              \n7- Tempo
              \n8- Gráficos
              \n0- Voltar""", ('1', '2', '3', '4', '5', '6', '7', '8', '0'))
    if opcao == '1':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Posição final, posição inicial, tempo inicial e tempo final
                              \n0- Voltar""", ('1', '0'))
      if opcao == '1':
        sfin = coleta_resposta("Insira a posição final (m)")
        sini = coleta_resposta("Insira a posição inicial (m)")
        tini = coleta_resposta("Insira o tempo inicial (s)")
        tfin = coleta_resposta("Insira o tempo final (s)")
        vmedia = velocidade_media(sfinal=sfin, sinicial=sini, tfinal=tfin, tinicial=tini)
        opcao_valida()
        print(f"A velocidade média é {vmedia} m/s")
    elif opcao == '2':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Posição final, posição inicial e tempo
                              \n0- Voltar""", ('1', '0'))
      if opcao == '1':
        sfin = coleta_resposta("Insira a posição final (m)")
        sini = coleta_resposta("Insira a posição inicial (m)")
        temp = coleta_resposta("Insira o tempo (s)")
        vel = sorvete(sinicial=sini, sfinal=sfin, tempo=temp)
      else:
        break
      opcao_valida()
      print(f"A velocidade é {vel} m/s")
    elif opcao == '3':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Velocidade média, posição final, tempo inicial e tempo final
                              \n2- Posição final, velocidade e tempo
                              \n0- Voltar""", ('1', '0'))
      if opcao == '1':
        vmedia = coleta_resposta("Insira a velocidade média (m/s)")
        sfin = coleta_resposta("Insira a posição final (m)")
        tini = coleta_resposta("Insira o tempo inicial (s)")
        tfin = coleta_resposta("Insira o tempo final (s)")
        sini = velocidade_media(sfinal=sfin, vmedia=vmedia, tinicial=tini, tfinal=tfin)
      elif opcao == '2':
        sfin = coleta_resposta("Insira a posição final (m)")
        vel = coleta_resposta("Insira a velocidade (m/s)")
        temp = coleta_resposta("Insira o tempo (s)")
        sini = sorvete(sinicial=sfin, velocidade=vel, tempo=temp)
      else:
        break
      opcao_valida()
      print(f"A posição inicial é {sini} m")
    elif opcao == '4':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Velocidade média, posição inicial, tempo inicial e tempo final
                              \n2- Posição inicial, velocidade, tempo
                              \n0- Voltar""", ('1', '2', '0'))
      if opcao == '1':
        vmedia = coleta_resposta("Insira a velocidade média (m/s)")
        sini = coleta_resposta("Insira a posição inicial (m)")
        tini = coleta_resposta("Insira o tempo inicial (s)")
        tfin = coleta_resposta("Insira o tempo final (s)")
        sfin = velocidade_media(sinicial=sini, vmedia=vmedia, tinicial=tini, tfinal=tfin)
      elif opcao == '2':
        sini = coleta_resposta("Insira a posição inicial (m)")
        vel = coleta_resposta("Insira a velocidade (m/s)")
        temp = coleta_resposta("Insira o tempo (s)")
        sfin = sorvete(sinicial=sini, velocidade=vel, tempo=temp)
      else:
        break
      opcao_valida()
      print(f"A posição final é {sfin} m")
    elif opcao == '5':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Velocidade média, posição inicial, posição final e tempo final
                              \n0- Voltar""", ('1', '0'))
      if opcao == '1':
        vmedia = coleta_resposta("Insira a velocidade média (m/s)")
        sini = coleta_resposta("Insira a posição inicial (m)")
        sfin = coleta_resposta("Insira a ppsição final (m)")
        tfin = coleta_resposta("Insira o tempo final (s)")
        tini = velocidade_media(sfinal=sfin, vmedia=vmedia, sinicial=sini, tfinal=tfin)
      else:
        break
      opcao_valida()
      print(f"O tempo inicial é {tini} s")
    elif opcao == '6':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Velocidade média, posição inicial, posição final e tempo inicial
                              \n0- Voltar""", ('1', '0'))
      if opcao == '1':
        vmedia = coleta_resposta("Insira a velocidade média (m/s)")
        sini = coleta_resposta("Insira a posição inicial (m)")
        sfin = coleta_resposta("Insira a ppsição final (m)")
        tini = coleta_resposta("Insira o tempo inicial (s)")
        tfin = velocidade_media(sfinal=sfin, vmedia=vmedia, sinicial=sini, tinicial=tini)
      else:
        break
      opcao_valida()
      print(f"O tempo final é {tfin} s")
    elif opcao == '7':
      opcao = coleta_resposta("""\nQue dados você possui?\n
                              \n1- Posição final, posição inicial e velocidade
                              \n0- Voltar""", ('1', '0'))
      if opcao == '1':
        sfin = coleta_resposta("Insira a posição final (m)")
        sini = coleta_resposta("Insira a posição inicial (m)")
        vel = coleta_resposta("Insira a velocidade (m/s)")
        temp = sorvete(sinicial=sini, sfinal=sfin, velocidade=vel)
      else:
        break
      opcao_valida()
      print(f"O tempo é {temp} s")
    elif opcao == '8':
      graficos()
    else:
      break

def graficos():
  """Menu de exibição de gráficos envolvendo movimento. Exibe todas as opções disponíveis (organizadas em submenus)
     e interage com o usuário para mostrar os gráficos desejados, chamando as funções pertinentes.

  Argumentos:
      None
      
  Retorno:
      None
  """

# roda o loop enquanto o usuário não selecionar a opção "voltar"
  while True:
    print_menu(' GRÁFICOS ')
    opcao = coleta_resposta("""\n1- Função horária das posições
                                \n2- Função horária das velocidades
                                \n0- Voltar""", ('1', '2', '0'))
    if opcao == '1':
      opcao = coleta_resposta("""\nDados necessários:\n
                              \nTempo final, tempo inicial, aceleracao, posicao inicial, velocidade inicial,
                              \npasso (distância entre os pontos no tempo)
                              \n1- Confirma
                              \n0- Voltar""", ('1', '0'))
      if opcao == '1':
        tfin = coleta_resposta("Insira o tempo final (s) (inteiro)", inteiro = True)
        tini = coleta_resposta("Insira o tempo inicial (s) (inteiro)", inteiro = True)
        acel = coleta_resposta("Insira a aceleração (m/s²)")
        sini = coleta_resposta("Insira a posição inicial (m)")
        vini = coleta_resposta("Insira a velocidade inicial (m/s)")
        passo = coleta_resposta("Insira o passo (s) (inteiro)", inteiro = True)
        plotar_funcao_horaria_posicoes(tfin, tini, acel, sini, vini, passo)
      else:
        break
    elif opcao == '2':
      opcao = coleta_resposta("""\nDados necessários:\n
                              \nVelocidade inicial, aceleração, tempo inicial, tempo final,
                              \npasso (distância entre os pontos no tempo)
                              \n1- Confirma
                              \n0- Voltar
                              """, ('1', '0'))
      if opcao == '1':
        vini = coleta_resposta("Insira a velocidade inicial (m/s)")
        acel = coleta_resposta("Insira a aceleração (m/s²)")
        tini = coleta_resposta("Insira o tempo inicial (s) (inteiro)", inteiro = True)
        tfin = coleta_resposta("Insira o tempo final (s) (inteiro)", inteiro = True)
        passo = coleta_resposta("Insira o passo (s) (inteiro)", inteiro = True)
        plotar_funcao_horaria_das_velocidades(vini, acel, tini, tfin, passo)
      else:
        break
    else:
      break

# roda o loop enquanto o usuário não selecionar a opção "sair"
while True:
  print_menu(' MENU INICIAL ')

  select = coleta_resposta("""\n1- Energia
                              \n2- Mola
                              \n3- Movimento
                              \n0- Sair""", ('1', '2', '3', '0'))

  if select == '1':
    menu_energia()
  elif select == '2':
    menu_mola()
  elif select == '3':
    menu_movimento()
  else:
    break

print('-'*76)
print(f"{' VOLTE SEMPRE ':^76}")
print('-'*76)
print()
cateto()
# Out:
# ------------------------------- MENU INICIAL -------------------------------
#
# 1- Energia
#
# 2- Mola
#
# 3- Movimento
#
# 0- Sair
#
# ...
#
# --------------------------------- ENERGIA ----------------------------------
#
# 1- Energia Cinética
#
# 2- Energia potencial gravitacional
#
# 3- Energia potencial elástica
#
# 4- Energia mecânica
#
# 0- Voltar
#
# ...
#
# ------------------------------- MENU INICIAL -------------------------------
#
# 1- Energia
#
# 2- Mola
#
# 3- Movimento
#
# 0- Sair
#
# ...
# ----------------------------------------------------------------------------
#                                 VOLTE SEMPRE
# ----------------------------------------------------------------------------
#
#                                 ▄▀▄     ▄▀▄
#                                ▄█░░▀▀▀▀▀░░█▄
#                            ▄▄  █░░░░░░░░░░░█  ▄▄
#                           █▄▄█ █░░▀░░┬░░▀░░█ █▄▄█
# ----------------------------------------------------------------------------
